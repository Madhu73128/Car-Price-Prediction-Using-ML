# %%
#importing necessary LIBRARIES
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
sns.set()

# %%
#importing DATASET
car_data=pd.read_csv('Car_Raw_Dataset.csv')
cd=car_data#for calculating deleted rows
car_data
# Out:
#               Brand     Price       Body  Mileage  EngineV Engine Type  \
# 0               BMW    4200.0      sedan      277      2.0      Petrol
# 1     Mercedes-Benz    7900.0        van      427      2.9      Diesel
# 2     Mercedes-Benz   13300.0      sedan      358      5.0         Gas
# 3              Audi   23000.0  crossover      240      4.2      Petrol
# 4            Toyota   18300.0  crossover      120      2.0      Petrol
# ...             ...       ...        ...      ...      ...         ...
# 4340  Mercedes-Benz  125000.0      sedan        9      3.0      Diesel
# 4341            BMW    6500.0      sedan        1      3.5      Petrol
# 4342            BMW    8000.0      sedan      194      2.0      Petrol
# 4343         Toyota   14200.0      sedan       31      NaN      Petrol
# 4344     Volkswagen   13500.0        van      124      2.0      Diesel
#
#      Registration  Year              Model
# 0             yes  1991                320
# ...

# %%
#Generating SUMMARY STATISTICS for the car data
car_data.describe()
# Out:
#                Price      Mileage      EngineV         Year
# count    4173.000000  4345.000000  4195.000000  4345.000000
# mean    19418.746935   161.237284     2.790734  2006.550058
# std     25584.242620   105.705797     5.066437     6.719097
# min       600.000000     0.000000     0.600000  1969.000000
# 25%      6999.000000    86.000000     1.800000  2003.000000
# 50%     11500.000000   155.000000     2.200000  2008.000000
# 75%     21700.000000   230.000000     3.000000  2012.000000
# max    300000.000000   980.000000    99.990000  2016.000000

# %%
#Generating SUMMARY STATISTICS for ALL COLUMNS, including CATEGORICAL DATA
car_data.describe(include='all')
# Out:
#              Brand          Price   Body      Mileage      EngineV  \
# count         4345    4173.000000   4345  4345.000000  4195.000000
# unique           7            NaN      6          NaN          NaN
# top     Volkswagen            NaN  sedan          NaN          NaN
# freq           936            NaN   1649          NaN          NaN
# mean           NaN   19418.746935    NaN   161.237284     2.790734
# std            NaN   25584.242620    NaN   105.705797     5.066437
# min            NaN     600.000000    NaN     0.000000     0.600000
# 25%            NaN    6999.000000    NaN    86.000000     1.800000
# 50%            NaN   11500.000000    NaN   155.000000     2.200000
# 75%            NaN   21700.000000    NaN   230.000000     3.000000
# max            NaN  300000.000000    NaN   980.000000    99.990000
#
#        Engine Type Registration         Year    Model
# count         4345         4345  4345.000000     4345
# ...

# %%
#Dropping the 'Model' column from car_data
car_data.drop('Model',axis=1,inplace=True)
print('Column Model of car_data is dropped')

#Generating SUMMARY STATISTICS for ALL COLUMNS, including CATEGORICAL DATA
car_data.describe(include='all')
# Out:
# Column Model of car_data is dropped
#              Brand          Price   Body      Mileage      EngineV  \
# count         4345    4173.000000   4345  4345.000000  4195.000000
# unique           7            NaN      6          NaN          NaN
# top     Volkswagen            NaN  sedan          NaN          NaN
# freq           936            NaN   1649          NaN          NaN
# mean           NaN   19418.746935    NaN   161.237284     2.790734
# std            NaN   25584.242620    NaN   105.705797     5.066437
# min            NaN     600.000000    NaN     0.000000     0.600000
# 25%            NaN    6999.000000    NaN    86.000000     1.800000
# 50%            NaN   11500.000000    NaN   155.000000     2.200000
# 75%            NaN   21700.000000    NaN   230.000000     3.000000
# max            NaN  300000.000000    NaN   980.000000    99.990000
#
#        Engine Type Registration         Year
# count         4345         4345  4345.000000
# ...

# %%
#Checking for the total number of missing values in each column of car_data
car_data.isnull().sum()
# Out:
# Brand             0
# Price           172
# Body              0
# Mileage           0
# EngineV         150
# Engine Type       0
# Registration      0
# Year              0
# dtype: int64

# %%
#Dropping rows with missing or null (NaN) values from car_data
car_data.dropna(axis=0,inplace=True)
print("Missing or Null(Nan) Values are dropped")

#Verifying that there are no remaining missing values in each column of car_data
car_data.isnull().sum()
# Out:
# Missing or Null(Nan) Values are dropped
# Brand           0
# Price           0
# Body            0
# Mileage         0
# EngineV         0
# Engine Type     0
# Registration    0
# Year            0
# dtype: int64

# %%
# Displaying the current state of the car_data DataFrame
car_data
# Out:
#               Brand     Price       Body  Mileage  EngineV Engine Type  \
# 0               BMW    4200.0      sedan      277      2.0      Petrol
# 1     Mercedes-Benz    7900.0        van      427      2.9      Diesel
# 2     Mercedes-Benz   13300.0      sedan      358      5.0         Gas
# 3              Audi   23000.0  crossover      240      4.2      Petrol
# 4            Toyota   18300.0  crossover      120      2.0      Petrol
# ...             ...       ...        ...      ...      ...         ...
# 4339         Toyota   17900.0      sedan       35      1.6      Petrol
# 4340  Mercedes-Benz  125000.0      sedan        9      3.0      Diesel
# 4341            BMW    6500.0      sedan        1      3.5      Petrol
# 4342            BMW    8000.0      sedan      194      2.0      Petrol
# 4344     Volkswagen   13500.0        van      124      2.0      Diesel
#
#      Registration  Year
# 0             yes  1991
# 1             yes  1999
# 2             yes  2003
# ...

# %%
#Generating SUMMARY STATISTICS for ALL COLUMNS, including CATEGORICAL DATA
car_data.describe(include='all')
# Out:
#              Brand          Price   Body      Mileage      EngineV  \
# count         4025    4025.000000   4025  4025.000000  4025.000000
# unique           7            NaN      6          NaN          NaN
# top     Volkswagen            NaN  sedan          NaN          NaN
# freq           880            NaN   1534          NaN          NaN
# mean           NaN   19552.308065    NaN   163.572174     2.764586
# std            NaN   25815.734988    NaN   103.394703     4.935941
# min            NaN     600.000000    NaN     0.000000     0.600000
# 25%            NaN    6999.000000    NaN    90.000000     1.800000
# 50%            NaN   11500.000000    NaN   158.000000     2.200000
# 75%            NaN   21900.000000    NaN   230.000000     3.000000
# max            NaN  300000.000000    NaN   980.000000    99.990000
#
#        Engine Type Registration         Year
# count         4025         4025  4025.000000
# unique           4            2          NaN
# ...

# %%
#Setting the figure size for the plot
plt.figure(figsize=(8,6))

#Plotting the distribution of car prices
sns.distplot(car_data['Price'])

#Adding a title to the plot
plt.title('Car price Distribution')
# Out:
# Text(0.5, 1.0, 'Car price Distribution')

# %%
#Calculating the 99th percentile value for the Price column to identify potential outliers
price_outlier=car_data['Price'].quantile(q=0.99)

#Displaying the 99th percentile value for the Price column
price_outlier
# Out:
# 129812.51999999981

# %%
price_modified_car_data=car_data[car_data['Price']<price_outlier]

price_modified_car_data.describe(include='all')
#modified_car_data
# Out:
#              Brand          Price   Body      Mileage      EngineV  \
# count         3984    3984.000000   3984  3984.000000  3984.000000
# unique           7            NaN      6          NaN          NaN
# top     Volkswagen            NaN  sedan          NaN          NaN
# freq           880            NaN   1528          NaN          NaN
# mean           NaN   17837.117460    NaN   165.116466     2.743770
# std            NaN   18976.268315    NaN   102.766126     4.956057
# min            NaN     600.000000    NaN     0.000000     0.600000
# 25%            NaN    6980.000000    NaN    93.000000     1.800000
# 50%            NaN   11400.000000    NaN   160.000000     2.200000
# 75%            NaN   21000.000000    NaN   230.000000     3.000000
# max            NaN  129222.000000    NaN   980.000000    99.990000
#
#        Engine Type Registration         Year
# count         3984         3984  3984.000000
# unique           4            2          NaN
# ...

# %%
plt.figure(figsize=(14,6))

plt.subplot(1,2,1)
sns.distplot(car_data['Price'])
plt.title("Before Removing Price Outliers")

plt.subplot(1,2,2)
sns.distplot(price_modified_car_data['Price'])
plt.xlim(0,129222)#(600,129222)
plt.title('After Removing Price Outliers')
# Out:
# Text(0.5, 1.0, 'After Removing Price Outliers')

# %%
plt.figure(figsize=(18,6))

plt.subplot(1,3,1)
sns.distplot(car_data['Mileage'])
plt.title('Car Mileage Distribution')

plt.subplot(1,3,2)
sns.distplot(car_data['EngineV'])
plt.title('Car Engine Volume Distribution')

plt.subplot(1,3,3)
sns.distplot(car_data['Year'])
plt.title('Car Year Distribution')
# Out:
# Text(0.5, 1.0, 'Car Year Distribution')

# %%
mileage_outlier=car_data['Mileage'].quantile(q=0.99)
mileage_outlier
# Out:
# 434.5199999999995

# %%
enginev_outlier=car_data['EngineV'].quantile(q=0.99)
enginev_outlier
# Out:
# 6.151999999999953

# %%
year_outlier=car_data['Year'].quantile(q=0.01)
year_outlier
# Out:
# 1987.0

# %%
mileage_modified_car_data=price_modified_car_data[price_modified_car_data['Mileage']<mileage_outlier]
enginev_modified_car_data=mileage_modified_car_data[mileage_modified_car_data['EngineV']<enginev_outlier]#0.6 to 6.5
year_modified_car_data=enginev_modified_car_data[enginev_modified_car_data['Year']>year_outlier]

year_modified_car_data.describe(include='all')
# Out:
#              Brand          Price   Body      Mileage      EngineV  \
# count         3850    3850.000000   3850  3850.000000  3850.000000
# unique           7            NaN      6          NaN          NaN
# top     Volkswagen            NaN  sedan          NaN          NaN
# freq           848            NaN   1457          NaN          NaN
# mean           NaN   18079.989639    NaN   160.766234     2.434325
# std            NaN   19006.352992    NaN    95.591098     0.918620
# min            NaN     800.000000    NaN     0.000000     0.600000
# 25%            NaN    7200.000000    NaN    92.000000     1.800000
# 50%            NaN   11600.000000    NaN   157.500000     2.200000
# 75%            NaN   21500.000000    NaN   226.000000     3.000000
# max            NaN  129222.000000    NaN   433.000000     6.000000
#
#        Engine Type Registration         Year
# count         3850         3850  3850.000000
# unique           4            2          NaN
# ...

# %%
plt.figure(figsize=(10,4))

plt.subplot(1,2,1)
sns.distplot(car_data['Mileage'])
plt.title('Before Removing Mileage Outliers')

plt.subplot(1,2,2)
sns.distplot(mileage_modified_car_data['Mileage'])
plt.xlim(0,433)
plt.title('After Removing Mileage outliers')
# Out:
# Text(0.5, 1.0, 'After Removing Mileage outliers')

# %%
plt.figure(figsize=(10,4))

plt.subplot(1,2,1)
sns.distplot(car_data['EngineV'])
plt.title('Before Removing EngineV Outliers')

plt.subplot(1,2,2)
sns.distplot(enginev_modified_car_data['EngineV'])
plt.xlim(0,6)
plt.title('After Removing EngineV Outliers')
# Out:
# Text(0.5, 1.0, 'After Removing EngineV Outliers')

# %%
plt.figure(figsize=(10,4))

plt.subplot(1,2,1)
sns.distplot(car_data['Year'])
plt.title('Before Removing Year Outliers')

plt.subplot(1,2,2)
sns.distplot(year_modified_car_data['Year'])
plt.xlim(1988,2016)
plt.title('After Removing Year Outliers')
# Out:
# Text(0.5, 1.0, 'After Removing Year Outliers')

# %%
clean_car_data=year_modified_car_data
clean_car_data
# Out:
#               Brand     Price       Body  Mileage  EngineV Engine Type  \
# 0               BMW    4200.0      sedan      277      2.0      Petrol
# 1     Mercedes-Benz    7900.0        van      427      2.9      Diesel
# 2     Mercedes-Benz   13300.0      sedan      358      5.0         Gas
# 3              Audi   23000.0  crossover      240      4.2      Petrol
# 4            Toyota   18300.0  crossover      120      2.0      Petrol
# ...             ...       ...        ...      ...      ...         ...
# 4338     Volkswagen   11500.0        van      163      2.5      Diesel
# 4339         Toyota   17900.0      sedan       35      1.6      Petrol
# 4340  Mercedes-Benz  125000.0      sedan        9      3.0      Diesel
# 4341            BMW    6500.0      sedan        1      3.5      Petrol
# 4344     Volkswagen   13500.0        van      124      2.0      Diesel
#
#      Registration  Year
# 0             yes  1991
# 1             yes  1999
# 2             yes  2003
# ...

# %%
clean_car_data=clean_car_data.reset_index(drop=True)
clean_car_data
# Out:
#               Brand     Price       Body  Mileage  EngineV Engine Type  \
# 0               BMW    4200.0      sedan      277      2.0      Petrol
# 1     Mercedes-Benz    7900.0        van      427      2.9      Diesel
# 2     Mercedes-Benz   13300.0      sedan      358      5.0         Gas
# 3              Audi   23000.0  crossover      240      4.2      Petrol
# 4            Toyota   18300.0  crossover      120      2.0      Petrol
# ...             ...       ...        ...      ...      ...         ...
# 3845     Volkswagen   11500.0        van      163      2.5      Diesel
# 3846         Toyota   17900.0      sedan       35      1.6      Petrol
# 3847  Mercedes-Benz  125000.0      sedan        9      3.0      Diesel
# 3848            BMW    6500.0      sedan        1      3.5      Petrol
# 3849     Volkswagen   13500.0        van      124      2.0      Diesel
#
#      Registration  Year
# 0             yes  1991
# 1             yes  1999
# 2             yes  2003
# ...

# %%
clean_car_data.describe(include='all')
# Out:
#              Brand          Price   Body      Mileage      EngineV  \
# count         3850    3850.000000   3850  3850.000000  3850.000000
# unique           7            NaN      6          NaN          NaN
# top     Volkswagen            NaN  sedan          NaN          NaN
# freq           848            NaN   1457          NaN          NaN
# mean           NaN   18079.989639    NaN   160.766234     2.434325
# std            NaN   19006.352992    NaN    95.591098     0.918620
# min            NaN     800.000000    NaN     0.000000     0.600000
# 25%            NaN    7200.000000    NaN    92.000000     1.800000
# 50%            NaN   11600.000000    NaN   157.500000     2.200000
# 75%            NaN   21500.000000    NaN   226.000000     3.000000
# max            NaN  129222.000000    NaN   433.000000     6.000000
#
#        Engine Type Registration         Year
# count         3850         3850  3850.000000
# unique           4            2          NaN
# ...

# %%
cd.shape[0]-clean_car_data.shape[0]
# Out:
# 495

# %%
#storing the clean_car_data to local memory in csv format for further preprocessing
clean_car_data.to_csv('cleaned_car_data.csv',index=False)
print('Save Successful')
# Out:
# Save Successful
